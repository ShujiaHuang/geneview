# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import geneview as gv

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
sinplot()

# %%
gv.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ffcc03dc0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ffcc03dc790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ffcc0357d30>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ffcc03dce50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffcc03e61f0>,
# ...
#  'means': []}

# %%
gv.set_style("dark")

# %%
sinplot()

# %%
gv.set_style("white")

# %%
sinplot()

# %%
gv.set_style("ticks")

# %%
sinplot()

# %%
sinplot()

# %%
data[0]
# Out:
# array([-0.06631917,  1.97554354,  0.64692493,  1.47430305,  2.37637952,
#         2.05281613])

# %%
gv.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.linewidth': 1.25,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 3.0,
#  'ytick.minor.size': 3.0,
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'image.cmap': 'Greys',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif']}

# %%
sns.set_style("darkgrid")
sinplot()

# %%
gv.set_style("darkgrid", {"axes.facecolor": ".1"})
sinplot()

# %%
gv.set_style("darkgrid", {"axes.facecolor": ".5"})
sinplot()

# %%
gv.palette._palettes._color_to_rgb((250, 75, 60), 'husl')
# Out:
# [0.3280665741712756, 0.5756593333508814, 0.8834912427673988]

# %%
gv.palette._palettes._ColorPalette((260, 75, 60))
# Out:
# [260, 75, 60]

# %%
'#%02x%02x%02x' % (135,177,255)
# Out:
# '#87b1ff'
